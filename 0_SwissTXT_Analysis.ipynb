# %% [markdown]
# ## Arena: Untertitel-Analyse
# Analyse der Untertiteldaten der SRF-Arena-Sendungen zwischen 2016 und 2019

# %%
### import libraries
import pandas as pd
import numpy as np
from datetime import datetime
import srt
import re
import os
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')

# %% [markdown]
# ### Untertitel bereinigen
# .srt-Dateien bereinigen und gemäss div. Merkmalen (wie z.B. Farbkodierung) Zeilen des Untertitels einzelnen Personen oder Ereignissen zuweisen

# %%
### remove html-tags from string
def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>|\(.*?\)')
    cleantext = re.sub(cleanr, '', raw_html)
    return cleantext

### tag lines in subtitles (if possible)
def identify_subtitles(subtitle):
    speaker = ["Moderator"]
    mask_host = "91FFFF"
    mask_others = None
    identified_subtitles = []
    
    for entry in subtitle:
        for line in entry.content.splitlines():
            ### Get clean string
            clean_line = cleanhtml(line)
                    
                    
            ### Switch between
            #### 1. Speaker indicated by parentheses
            #### 2. Speaker highlighted by color (in a special case = moderator)
            #### 3. Comment
            #### 4. Everything else
            
            if line.find("(") != -1:
                speaker.append(line[line.find("(")+1:line.find(")")])
            elif (line[0] == "<"):
                if mask_host == line[13:19]:
                    speaker.append("Moderator")
                else:
                    speaker.append("Gast")
            elif line.find("*") != -1:
                speaker.append("<---> Kommentar <--->")
            else:
                if ((speaker[-1] == "Moderator") or (speaker[-1] == "<---> Kommentar <--->")):
                    speaker.append("Gast")
            identified_subtitles.append([speaker[-1], clean_line.lstrip()])
    return identified_subtitles

# %%
### define data directory and initialize variables
directory = "data/"
words_moderator = 0
words_rest = 0
comments = []

### loop over .srt-files
for filename in os.listdir(directory):
    if (("srt" in filename)):
        with open(directory+filename, "rb") as file:
            ### decode and parse data
            data = file.read().decode("iso-8859-1")
            subtitle_generator = srt.parse(data)
            subtitle = list(subtitle_generator)
            identified_subtitles = identify_subtitles(subtitle)
            
            ### handle 1. counter for host, 2. comments and 3. counter for rest
            for line in identified_subtitles:
                if line[0] == "Moderator":
                    words_moderator += len(tokenizer.tokenize(line[1]))
                elif line[0] == "<---> Kommentar <--->":
                    comments.append([filename, line[1]])
                else:
                    words_rest += len(tokenizer.tokenize(line[1]))

# %% [markdown]
# ---

# %% [markdown]
# ### Kommentare auslesen und bereinigen

# %%
### create dataframe for comments
comments = pd.DataFrame(comments, columns = ["file", "comment"])
comments["counter"] = 1
comments["date"] = comments["file"].apply(lambda x: x[6:14])

# %%
### look at existing values
comments.groupby(["date", "comment"]).count().reset_index()["comment"].unique()
# Out:
# array(['* Bedrohlicher Geigenton *', '* Er spricht Arabisch. *',
#        '* Fröhliche türkische Musik *', '* Klingeln *', '* Lachen *',
#        '* Muezzinruf *', '* Sie sprechen durcheinander. *',
#        '* Signalton *', '* Applaus *', '* Andreas Glarner lacht. *',
#        '* Sie sprechen durcheinander *', '* Spannungsgeladene Musik *',
#        '* Das Publikum lacht. *', '* Filippo Lombardi ruft',
#        '* Sie reden durcheinander. *', 'etwas Unverständliches. *',
#        '* Ausruf von Mitleid *', '* Jubel *',
#        '* Schweizer Nationalhymne *', '* Vereinzelter Applaus *',
#        '* Verhaltener Applaus *', '* Lachen im Publikum *',
#        '* Tilman Slembeck', 'sagt etwas Unverständliches. *',
#        '* Tamara Funiciello lacht. *', '* Orgelmusik *',
#        '* Lachen im Studio *', '* Sirene *', '* Christoph Blocher',
#        '* Christoph Blocher murmelt etwas. *',
#        'murmelt etwas Unverständliches. *', '* Lachen, Applaus *',
#        '* Einzelner Applaus *', '* Gemütlicher Rapsong',
#        '* Lachen und Applaus *', 'von Tommy Vercetti *',
#        '* "Stille Nacht" auf Blockflöte *',
#        '* Sie sprechen gleichzeitig. *',
#        '* Unverständlicher Zwischenruf *', '* Protestrufe *',
#        '* Unverständlicher Einwurf *', '* Er äfft sie nach. *',
#        '* Lachen und vereinzelter Applaus *', '* Zögerlicher Applaus *',
#        '* Allgemeines Schmunzeln *', '* Husten *',
#        '* Unverständlicher Einwand *', '* Lautes Lachen im Publikum *',
#        'Interesse der EU. * Signalton *', '* Markus Ritter',
#        '* Leises Lachen *', '* Klatschen *',
#        '* Lachen aus dem Publikum *', '* Gelächter *', '* Buzzer *',
#        '* Sie sprechen durcheinander.*', '* Seufzer *',
#        '* Applaus und Jubelrufe *', '* Muhen *',
#        '* Elektronische Klänge *', '* Spannungsgeladene Klänge *',
#        '* Europäische Hymne *', '* Video *',
#        '* Sie sprechen durcheinander. "',
#        '* Jauchzer und Alphornklänge *', '* Jodelgesang *',
#        '* Elektronische Musik *'], dtype=object)

# %%
### clean values by grouping ###
#### 1. "durcheinander reden" ####
comments.loc[comments.comment == "* Sie sprechen durcheinander *", 'comment'] = "* Sie sprechen durcheinander. *"
comments.loc[comments.comment == "* Sie reden durcheinander. *", 'comment'] = "* Sie sprechen durcheinander. *"
comments.loc[comments.comment == "* Sie sprechen durcheinander.*", 'comment'] = "* Sie sprechen durcheinander. *"
comments.loc[comments.comment == '* Sie sprechen durcheinander. "', 'comment'] = "* Sie sprechen durcheinander. *"
comments.loc[comments.comment == '* Sie sprechen gleichzeitig. *', 'comment'] = "* Sie sprechen durcheinander. *"
comments.loc[comments.comment == '* Unverständlicher Zwischenruf *', 'comment'] = "* Sie sprechen durcheinander. *"
comments.loc[comments.comment == '* Protestrufe *', 'comment'] = "* Sie sprechen durcheinander. *"
comments.loc[comments.comment == '* Unverständlicher Einwurf *', 'comment'] = "* Sie sprechen durcheinander. *"
comments.loc[comments.comment == '* Unverständlicher Einwand *', 'comment'] = "* Sie sprechen durcheinander. *"


#### 2. "Heiterkeit" ####
comments.loc[comments.comment == '* Das Publikum lacht. *', 'comment'] = "* Lachen *"
comments.loc[comments.comment == '* Lachen im Publikum *', 'comment'] = "* Lachen *"
comments.loc[comments.comment == "* Lachen im Studio *", 'comment'] = "* Lachen *"
comments.loc[comments.comment == "* Andreas Glarner lacht. *", 'comment'] = "* Lachen *"
comments.loc[comments.comment == "* Jubel *", 'comment'] = "* Lachen *"
comments.loc[comments.comment == "* Tamara Funiciello lacht. *", 'comment'] = "* Lachen *"
comments.loc[comments.comment == "* Lachen, Applaus *", 'comment'] = "* Lachen *"
comments.loc[comments.comment == "* Lachen und Applaus *", 'comment'] = "* Lachen *"
comments.loc[comments.comment == "* Lachen und vereinzelter Applaus *", 'comment'] = "* Lachen *"
comments.loc[comments.comment == "* Allgemeines Schmunzeln *", 'comment'] = "* Lachen *"
comments.loc[comments.comment == "* Lautes Lachen im Publikum *", 'comment'] = "* Lachen *"
comments.loc[comments.comment == "* Leises Lachen *", 'comment'] = "* Lachen *"
comments.loc[comments.comment == "* Lachen aus dem Publikum *", 'comment'] = "* Lachen *"
comments.loc[comments.comment == "* Gelächter *", 'comment'] = "* Lachen *"
comments.loc[comments.comment == "* Applaus und Jubelrufe *", 'comment'] = "* Lachen *"

# %%
### count different comments by date
comment_counter = comments[["date", "comment", "counter"]].groupby(["date", "comment"]).count().reset_index().sort_values(by="counter", ascending=False)

# %% [markdown]
# ---

# %% [markdown]
# ### Titel der Arena-Sendungen ermitteln
# Sendungen nach Datum suchen und über https://www.srf.ch/sendungen/arena Titel, Beschreibungen und Gäste der Sendungen ermitteln

# %%
### import libraries
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException
from pathlib import Path
import json
import requests
import time
import re

# %%
### replace certain (wrong) dates
def replace_date(date):
    result = {
        "20160924" : "20160923",
        "20160531" : "20160527"
    }
    if date in result.keys():
        return(result[date])
    else:
        return(date)

# %%
### initialize variables
sendungen = []

### start browser and visit srf.ch
driver = webdriver.Chrome("./tools/chromedriver")
driver.get("https://www.srf.ch/sendungen/arena")

### reveal all entries back to 2016
for i in range(15):
    driver.find_element_by_class_name("btn-reveal").click()
    time.sleep(2)
    i += 1

### find entry by date and save title, description and link
for date in comment_counter.date.unique():
    date_check = replace_date(date)
    if (datetime.strptime(date_check, "%Y%m%d") > datetime.strptime("20190208", "%Y%m%d")):
        a_tag = (driver.find_element_by_xpath("//*[contains(text(), '{}')]/preceding-sibling::h3/a".format(datetime.strptime(date_check, "%Y%m%d").strftime("%-d.%-m.%Y"))))
        title = a_tag.text
        link = a_tag.get_attribute('href')
        description = (driver.find_element_by_xpath("//*[contains(text(), '{}')]/following-sibling::p".format(datetime.strptime(date_check, "%Y%m%d").strftime("%-d.%-m.%Y"))).text)
    else:
        a_tag = (driver.find_element_by_xpath("//*[contains(text(), '{}')]/preceding-sibling::h3/a".format(datetime.strptime(date_check, "%Y%m%d").strftime("%d.%m.%Y"))))
        title = a_tag.text
        link = a_tag.get_attribute('href')
        description = (driver.find_element_by_xpath("//*[contains(text(), '{}')]/following-sibling::p".format(datetime.strptime(date_check, "%Y%m%d").strftime("%d.%m.%Y"))).text)
    sendungen.append([date, title, description, link])

# %%
### create new dataframe and save data to csv
sendungen = pd.DataFrame(sendungen, columns = ["date", "title", "description", "link"])
sendungen.to_csv("data/sendungen.csv")

# %%
### join data (comments and shows)
comment_counter = pd.merge(comment_counter,
                           sendungen,
                           left_on="date",
                           right_on="date",
                           how="left")

# %%
### Initialize variable
guests = []
### Start browser
driver = webdriver.Chrome("./tools/chromedriver")
### visit each webpage of each show. then find and save guests.
for idx, row in sendungen.iterrows():
    driver.get(row.link)
    time.sleep(2)
    text_element = driver.find_element_by_xpath("/html[1]/body[1]/div[1]/div[2]/div[1]/div[1]/article[1]/div[1]/div[3]")
    list_elements = text_element.find_elements_by_tag_name("li")
    for elem in list_elements:
        full_desc = (elem.text).split(",")
        if len(full_desc) > 1:
            name = full_desc[0]
            title = full_desc[1]
        else:
            name = ""
            title = elem.text
        guests.append([row.date, name, title])
driver.close()
guests = pd.DataFrame(guests, columns=["date", "name", "title"])

# %%
### clean data
guests = guests[guests.name != ""]
guests.loc[guests.date == "20181116", 'title'] = guests[guests.date == "20181116"].name.apply(lambda x: x[x.find("(")+1:x.find(")")])
guests.loc[guests.date == "20181116", 'name'] = guests[guests.date == "20181116"].name.apply(lambda x: x[:x.find("(")-1])
guests = guests[guests.name != "Sollte der Finanzausgleich zwischen den Kantonen abgeschafft werden"]
guests = guests[~guests.title.str.contains("die wir selber vielleicht gar nicht brauchen?")]

# %%
### save data as csv
guests.to_csv("data/gaeste_nach_sendung.csv")
comment_counter.to_csv("data/kommentare.csv")

# %% [markdown]
# ---

# %% [markdown]
# ### Auswertungen

# %%
### look at most "chaotic" shows
pd.concat([comment_counter[comment_counter.comment == "* Sie sprechen durcheinander. *"], sendungen], sort=False).sort_values(by="counter", ascending=False)
# Out:
#         date                          comment  counter  \
# 0   20181123  * Sie sprechen durcheinander. *     31.0
# 2   20161118  * Sie sprechen durcheinander. *     21.0
# 1   20170929  * Sie sprechen durcheinander. *     21.0
# 3   20180309  * Sie sprechen durcheinander. *     20.0
# 4   20170526  * Sie sprechen durcheinander. *     20.0
# 5   20171117  * Sie sprechen durcheinander. *     19.0
# 6   20170922  * Sie sprechen durcheinander. *     17.0
# 7   20161104  * Sie sprechen durcheinander. *     17.0
# 8   20170407  * Sie sprechen durcheinander. *     17.0
# 9   20170505  * Sie sprechen durcheinander. *     15.0
# 10  20161202  * Sie sprechen durcheinander. *     15.0
# 11  20161111  * Sie sprechen durcheinander. *     13.0
# 13  20170901  * Sie sprechen durcheinander. *     11.0
# 14  20160610  * Sie sprechen durcheinander. *     11.0
# 16  20180518  * Sie sprechen durcheinander. *     10.0
# 17  20170317  * Sie sprechen durcheinander. *      9.0
# 18  20170324  * Sie sprechen durcheinander. *      9.0
# 19  20190201  * Sie sprechen durcheinander. *      9.0
# 25  20190222  * Sie sprechen durcheinander. *      8.0
# 23  20180921  * Sie sprechen durcheinander. *      8.0
# 22  20160924  * Sie sprechen durcheinander. *      8.0
# 21  20180907  * Sie sprechen durcheinander. *      8.0
# 20  20160422  * Sie sprechen durcheinander. *      8.0
# 26  20160826  * Sie sprechen durcheinander. *      7.0
# 27  20190215  * Sie sprechen durcheinander. *      7.0
# 28  20161014  * Sie sprechen durcheinander. *      7.0
# 30  20171215  * Sie sprechen durcheinander. *      7.0
# 37  20160617  * Sie sprechen durcheinander. *      6.0
# 40  20181116  * Sie sprechen durcheinander. *      6.0
# 39  20171110  * Sie sprechen durcheinander. *      6.0
# ..       ...                              ...      ...
# 55  20170428                              NaN      NaN
# 56  20180504                              NaN      NaN
# 57  20160513                              NaN      NaN
# 58  20160506                              NaN      NaN
# 59  20170303                              NaN      NaN
# 60  20170310                              NaN      NaN
# 61  20160930                              NaN      NaN
# 62  20160408                              NaN      NaN
# 63  20170421                              NaN      NaN
# 64  20180323                              NaN      NaN
# 65  20171006                              NaN      NaN
# 66  20180928                              NaN      NaN
# 67  20160902                              NaN      NaN
# 68  20180119                              NaN      NaN
# 69  20171208                              NaN      NaN
# 70  20171103                              NaN      NaN
# 71  20171201                              NaN      NaN
# 72  20171020                              NaN      NaN
# 73  20180126                              NaN      NaN
# 74  20180914                              NaN      NaN
# 75  20180525                              NaN      NaN
# 76  20181012                              NaN      NaN
# 77  20160531                              NaN      NaN
# 78  20161028                              NaN      NaN
# 79  20190118                              NaN      NaN
# 80  20160429                              NaN      NaN
# 81  20161216                              NaN      NaN
# 82  20160909                              NaN      NaN
# 83  20160916                              NaN      NaN
# 84  20160520                              NaN      NaN
#
#                                                 title  \
# 0                              Gekaufte Abstimmungen?
# 2                     Kapitalismus oder Klassenkampf?
# 1                                     Am runden Tisch
# 3                  Blocher – auf zum letzten Gefecht!
# 4                               Die Parteipräsidenten
# 5                                 Profit statt Moral?
# 6                                  Blocher gegen alle
# 7                          Wer hat das Sagen im Land?
# 8                                         Die Attacke
# 9                              Sind wir zu freizügig?
# 10                          Zuwanderung: Der Showdown
# 11                                       Wieso Trump?
# 13                            Wer rettet meine Rente?
# 14                                    Frauen am Herd?
# 16                  Sollen Tamynique heiraten dürfen?
# 17                                      Fremde Redner
# 18                                     Auf in die EU?
# 19                Spitzenmedizin, aber bitte günstig!
# 25                           Achtung, fertig, Wahlen!
# 23       Präsidenten-«Arena»: Politik am Volk vorbei?
# 22  «Inländervorrang light» - ist das der Volkswille?
# 21            Schweizer Waffen in Bürgerkriegsländer?
# 20              Abstimmungs-Arena: Asylgesetzrevision
# 26                            Arena: An der Südgrenze
# 27                              Alle Macht den Alten?
# 28  Jobs weg, Freiheit weg – globalisieren wir die...
# 30                         Schnüffeln im Sozialstaat?
# 37                  Gut genug für den Schweizer Pass?
# 40                                    Unser Europarat
# 39  Kampf um die Jets – Bundesrat Parmelin in der ...
# ..                                                ...
# 55              Abstimmungs-Arena: «Energiestrategie»
# 56                EU-Debatte – die Wirtschaft erwacht
# 57       Abstimmungs-Arena: Service-Public-Initiative
# 58             Abstimmungs-Arena: Milchkuh-Initiative
# 59                        Rentenreform auf der Kippe?
# 60             Sollte die nicht bei den Kindern sein?
# 61          Rentenreform 2020: Rettung oder Reinfall?
# 62                                 Schweiz ohne Gott?
# 63                                  Ü50 - chancenlos?
# 64                        Sparen bei den Schwächsten?
# 65                      Burka – da sehen wir schwarz!
# 66          Doppelrücktritt – Bremse fürs EU-Dossier?
# 67     Abstimmungs-Arena: Initiative Grüne Wirtschaft
# 68             «Abstimmungsarena»: Finanzordnung 2021
# 69                            Was stoppt Terroristen?
# 70                          No Billag - Ja oder Nein?
# 71                                   Impf oder stirb?
# 72                              Ungebremste Mobilität
# 73                                     Trump vs. WEF!
# 74          «Abstimmungs-Arena»: Fair-Food-Initiative
# 75               «Abstimmungs-Arena»: Geldspielgesetz
# 76                   Fahren wir die Welt an die Wand?
# 77              Service Public – die Publikumsdebatte
# 78      Abstimmungs-Arena: «Atomausstiegs-Initiative»
# 79                             Die Jungen übernehmen!
# 80  Abstimmungs-Arena: Änderung Fortpflanzungsmedizin
# 81                                  Schöne Bescherung
# 82  Abstimmungs-Arena: Referendum Nachrichtendiens...
# 83             Abstimmungs-Arena: Initiative AHV Plus
# 84       Abstimmungs-Arena: Initiative Grundeinkommen
#
#                                           description  \
# 0   Befürworter wie auch Gegner der Selbstbestimmu...
# 2   Trump gewinnt, Europa rutscht nach rechts. Abe...
# 1   Ob Unternehmenssteuer oder Altersvorsorge: In ...
# 3   Nun geht es Schlag auf Schlag: Am Montag präse...
# 4   Fast ist Halbzeit in Bern: Was hat die erste L...
# 5   Steuervermeidung und Rohstoffhandel: Von beide...
# 6   Ob der neue Aussenminister nun Ignazio Cassis ...
# 7   Unterdessen ist klar: Die Masseneinwanderungsi...
# 8   Die SVP zielt auf die Menschenrechts-Konventio...
# 9   Europa wird immer EU-kritischer: In Frankreich...
# 10  Die Zeit drängt: Bis am 9. Februar 2017 muss d...
# 11  Wie war diese Wahl möglich? Diese Frage stelle...
# 13  Nun greift Dreifuss ein! Für die grosse Renten...
# 14  Wieso bleiben so viele gut ausgebildete Frauen...
# 16  Auch homosexuelle Paare in der Schweiz sollen ...
# 17  Laute Proteste, angekündigte Demonstrationen u...
# 18  Vor 25 Jahren war der EU-Beitritt für viele ei...
# 19  Das Bundesgericht hat ein Machtwort gesprochen...
# 25  SP und SVP verlieren, Grüne und Grünliberale g...
# 23  Während beim Rahmenabkommen ein Abschluss in w...
# 22  Der Nationalrat debattierte am Mittwoch über d...
# 21  Der Bundesrat will die Exportbestimmungen für ...
# 20  In einem sind sich alle einig: Lange Asylverfa...
# 26  Sie sitzen seit Wochen in Como fest. Sie sind ...
# 27  Jahr für Jahr werden wir älter – und zwar nich...
# 28  Neue globale Handelsabkommen wie TTIP sollen d...
# 30  Die Überwachung von IV-Bezügern soll erlaubt w...
# 37  Die Schweiz hat europaweit eines der strengste...
# 40  Ob beim Referendum gegen Versicherungsdetektiv...
# 39  Neue Kampfjets – dafür will der Bundesrat bis ...
# ..                                                ...
# 55  Langfristig aus der Kernenergie aussteigen und...
# 56  Der Bundesrat will es, fast alle Parteien woll...
# 57  Managerlöhne bei Post, SBB und Swisscom sollen...
# 58  Mehr Geld für die Strasse – das will die sogen...
# 59  Es braucht eine Rentenreform – darin sind sich...
# 60  Wieso ist die nicht bei ihren Kindern? Das hör...
# 61  Die Zukunft unserer Renten – darüber debattier...
# 62  Zwei muslimische Schüler wollen ihrer Lehrerin...
# 63  Den Job zu verlieren – der Albtraum jedes Arbe...
# 64  Die Schraube anziehen bei den Armen – das woll...
# 65  Die Burka gibt zu reden. In Österreich ist sie...
# 66  Bundesrat Johann Schneider-Ammann tritt zurück...
# 67  Einen ökologischen Fussabdruck von einer Erde:...
# 68  Darf der Bund weiterhin Steuern erheben? Ja, s...
# 69  Weihnachtsmärkte in der Schweiz setzen dieses ...
# 70  Ist die SRG, wie wir sie kennen, bald Geschich...
# 71  Die Grippezeit steht kurz bevor. Sollte man si...
# 72  Stau auf den Strassen, verspätete Züge, vollge...
# 73  Donald Trump und das WEF – da treffen Welten a...
# 74  Isst die Schweiz fair genug? Nein, finden die ...
# 75  Das neue Geldspielgesetz schien beschlossene S...
# 76  Der Meeresspiegel steigt, extreme Wetterereign...
# 77  Sämtliche Parlamentarier haben gegen die Servi...
# 78  Nach 45 Jahren Laufzeit müssen Kernkraftwerke ...
# 79  Sara (17), Luis (17) und Andrea (17) moderiere...
# 80  Darf man Embryonen, die im Reagenzglas entsteh...
# 81  Rund ums Jahr streiten Politiker in der «Arena...
# 82  Telefongespräche abhören, Wanzen in Privaträum...
# 83  Zehn Prozent mehr AHV-Rente, das fordert die I...
# 84  Lohn ohne Arbeit, Geld ohne Gegenleistung - ei...
#
#                                                  link
# 0   https://www.srf.ch/sendungen/arena/gekaufte-ab...
# 2   https://www.srf.ch/sendungen/arena/kapitalismu...
# 1   https://www.srf.ch/sendungen/arena/am-runden-t...
# 3   https://www.srf.ch/sendungen/arena/blocher-auf...
# 4   https://www.srf.ch/sendungen/arena/die-parteip...
# 5   https://www.srf.ch/sendungen/arena/profit-stat...
# 6   https://www.srf.ch/sendungen/arena/blocher-geg...
# 7   https://www.srf.ch/sendungen/arena/wer-hat-das...
# 8      https://www.srf.ch/sendungen/arena/die-attacke
# 9   https://www.srf.ch/sendungen/arena/sind-wir-zu...
# 10  https://www.srf.ch/sendungen/arena/zuwanderung...
# 11     https://www.srf.ch/sendungen/arena/wieso-trump
# 13  https://www.srf.ch/sendungen/arena/wer-rettet-...
# 14  https://www.srf.ch/sendungen/arena/frauen-am-herd
# 16  https://www.srf.ch/sendungen/arena/sollen-tamy...
# 17   https://www.srf.ch/sendungen/arena/fremde-redner
# 18   https://www.srf.ch/sendungen/arena/auf-in-die-eu
# 19  https://www.srf.ch/sendungen/arena/spitzenmedi...
# 25  https://www.srf.ch/sendungen/arena/achtung-fer...
# 23  https://www.srf.ch/sendungen/arena/praesidente...
# 22  https://www.srf.ch/sendungen/arena/inlaendervo...
# 21  https://www.srf.ch/sendungen/arena/schweizer-w...
# 20  https://www.srf.ch/sendungen/arena/abstimmungs...
# 26  https://www.srf.ch/sendungen/arena/arena-an-de...
# 27  https://www.srf.ch/sendungen/arena/alle-macht-...
# 28  https://www.srf.ch/sendungen/arena/jobs-weg-fr...
# 30  https://www.srf.ch/sendungen/arena/schnueffeln...
# 37  https://www.srf.ch/sendungen/arena/gut-genug-f...
# 40  https://www.srf.ch/sendungen/arena/unser-europ...
# 39  https://www.srf.ch/sendungen/arena/kampf-um-di...
# ..                                                ...
# 55  https://www.srf.ch/sendungen/arena/abstimmungs...
# 56  https://www.srf.ch/sendungen/arena/eu-debatte-...
# 57  https://www.srf.ch/sendungen/arena/abstimmungs...
# 58  https://www.srf.ch/sendungen/arena/abstimmungs...
# 59  https://www.srf.ch/sendungen/arena/rentenrefor...
# 60  https://www.srf.ch/sendungen/arena/sollte-die-...
# 61  https://www.srf.ch/sendungen/arena/rentenrefor...
# 62  https://www.srf.ch/sendungen/arena/schweiz-ohn...
# 63  https://www.srf.ch/sendungen/arena/ue50-chance...
# 64  https://www.srf.ch/sendungen/arena/sparen-bei-...
# 65  https://www.srf.ch/sendungen/arena/burka-da-se...
# 66  https://www.srf.ch/sendungen/arena/doppelrueck...
# 67  https://www.srf.ch/sendungen/arena/abstimmungs...
# 68  https://www.srf.ch/sendungen/arena/abstimmungs...
# 69  https://www.srf.ch/sendungen/arena/was-stoppt-...
# 70  https://www.srf.ch/sendungen/arena/no-billag-j...
# 71  https://www.srf.ch/sendungen/arena/impf-oder-s...
# 72  https://www.srf.ch/sendungen/arena/ungebremste...
# 73    https://www.srf.ch/sendungen/arena/trump-vs-wef
# 74  https://www.srf.ch/sendungen/arena/abstimmungs...
# 75  https://www.srf.ch/sendungen/arena/abstimmungs...
# 76  https://www.srf.ch/sendungen/arena/fahren-wir-...
# 77  https://www.srf.ch/sendungen/arena/service-pub...
# 78  https://www.srf.ch/sendungen/arena/abstimmungs...
# 79  https://www.srf.ch/sendungen/arena/die-jungen-...
# 80  https://www.srf.ch/sendungen/arena/abstimmungs...
# 81  https://www.srf.ch/sendungen/arena/schoene-bes...
# 82  https://www.srf.ch/sendungen/arena/abstimmungs...
# 83  https://www.srf.ch/sendungen/arena/abstimmungs...
# 84  https://www.srf.ch/sendungen/arena/abstimmungs...
#
# [164 rows x 6 columns]

# %%
### look at most "funny" shows
pd.concat([comment_counter[comment_counter.comment == "* Lachen *"], sendungen], sort=False).sort_values(by="counter", ascending=False)
# Out:
#          date     comment  counter  \
# 12   20170519  * Lachen *     13.0
# 24   20161111  * Lachen *      8.0
# 29   20170922  * Lachen *      7.0
# 42   20180622  * Lachen *      6.0
# 57   20180105  * Lachen *      4.0
# 66   20181102  * Lachen *      4.0
# 89   20171006  * Lachen *      3.0
# 96   20180119  * Lachen *      3.0
# 95   20160617  * Lachen *      3.0
# 93   20161118  * Lachen *      3.0
# 85   20171110  * Lachen *      3.0
# 83   20180518  * Lachen *      3.0
# 82   20190215  * Lachen *      3.0
# 74   20160506  * Lachen *      3.0
# 70   20160513  * Lachen *      3.0
# 133  20160422  * Lachen *      2.0
# 145  20170303  * Lachen *      2.0
# 142  20170331  * Lachen *      2.0
# 138  20181026  * Lachen *      2.0
# 137  20181012  * Lachen *      2.0
# 148  20180921  * Lachen *      2.0
# 126  20160924  * Lachen *      2.0
# 116  20170929  * Lachen *      2.0
# 110  20171103  * Lachen *      2.0
# 101  20171201  * Lachen *      2.0
# 123  20161014  * Lachen *      2.0
# 219  20170526  * Lachen *      1.0
# 241  20170324  * Lachen *      1.0
# 240  20161216  * Lachen *      1.0
# 238  20161125  * Lachen *      1.0
# ..        ...         ...      ...
# 55   20170428         NaN      NaN
# 56   20180504         NaN      NaN
# 57   20160513         NaN      NaN
# 58   20160506         NaN      NaN
# 59   20170303         NaN      NaN
# 60   20170310         NaN      NaN
# 61   20160930         NaN      NaN
# 62   20160408         NaN      NaN
# 63   20170421         NaN      NaN
# 64   20180323         NaN      NaN
# 65   20171006         NaN      NaN
# 66   20180928         NaN      NaN
# 67   20160902         NaN      NaN
# 68   20180119         NaN      NaN
# 69   20171208         NaN      NaN
# 70   20171103         NaN      NaN
# 71   20171201         NaN      NaN
# 72   20171020         NaN      NaN
# 73   20180126         NaN      NaN
# 74   20180914         NaN      NaN
# 75   20180525         NaN      NaN
# 76   20181012         NaN      NaN
# 77   20160531         NaN      NaN
# 78   20161028         NaN      NaN
# 79   20190118         NaN      NaN
# 80   20160429         NaN      NaN
# 81   20161216         NaN      NaN
# 82   20160909         NaN      NaN
# 83   20160916         NaN      NaN
# 84   20160520         NaN      NaN
#
#                                                  title  \
# 12                              Eine tierische «Arena»
# 24                                        Wieso Trump?
# 29                                  Blocher gegen alle
# 42   SRG und Private – wer profitiert vom neuen Med...
# 57                   No Billag - jetzt redet das Volk!
# 66             «Abstimmungs-Arena»: Hornkuh-Initiative
# 89                       Burka – da sehen wir schwarz!
# 96              «Abstimmungsarena»: Finanzordnung 2021
# 95                   Gut genug für den Schweizer Pass?
# 93                     Kapitalismus oder Klassenkampf?
# 85   Kampf um die Jets – Bundesrat Parmelin in der ...
# 83                   Sollen Tamynique heiraten dürfen?
# 82                               Alle Macht den Alten?
# 74              Abstimmungs-Arena: Milchkuh-Initiative
# 70        Abstimmungs-Arena: Service-Public-Initiative
# 133              Abstimmungs-Arena: Asylgesetzrevision
# 145                        Rentenreform auf der Kippe?
# 142                                  Klick, Like, Hass
# 138  «Abstimmungs-Arena»: Überwachung Sozialversich...
# 137                   Fahren wir die Welt an die Wand?
# 148       Präsidenten-«Arena»: Politik am Volk vorbei?
# 126  «Inländervorrang light» - ist das der Volkswille?
# 116                                    Am runden Tisch
# 110                          No Billag - Ja oder Nein?
# 101                                   Impf oder stirb?
# 123  Jobs weg, Freiheit weg – globalisieren wir die...
# 219                              Die Parteipräsidenten
# 241                                     Auf in die EU?
# 240                                  Schöne Bescherung
# 238                                 Vergoldete Bauern?
# ..                                                 ...
# 55               Abstimmungs-Arena: «Energiestrategie»
# 56                 EU-Debatte – die Wirtschaft erwacht
# 57        Abstimmungs-Arena: Service-Public-Initiative
# 58              Abstimmungs-Arena: Milchkuh-Initiative
# 59                         Rentenreform auf der Kippe?
# 60              Sollte die nicht bei den Kindern sein?
# 61           Rentenreform 2020: Rettung oder Reinfall?
# 62                                  Schweiz ohne Gott?
# 63                                   Ü50 - chancenlos?
# 64                         Sparen bei den Schwächsten?
# 65                       Burka – da sehen wir schwarz!
# 66           Doppelrücktritt – Bremse fürs EU-Dossier?
# 67      Abstimmungs-Arena: Initiative Grüne Wirtschaft
# 68              «Abstimmungsarena»: Finanzordnung 2021
# 69                             Was stoppt Terroristen?
# 70                           No Billag - Ja oder Nein?
# 71                                    Impf oder stirb?
# 72                               Ungebremste Mobilität
# 73                                      Trump vs. WEF!
# 74           «Abstimmungs-Arena»: Fair-Food-Initiative
# 75                «Abstimmungs-Arena»: Geldspielgesetz
# 76                    Fahren wir die Welt an die Wand?
# 77               Service Public – die Publikumsdebatte
# 78       Abstimmungs-Arena: «Atomausstiegs-Initiative»
# 79                              Die Jungen übernehmen!
# 80   Abstimmungs-Arena: Änderung Fortpflanzungsmedizin
# 81                                   Schöne Bescherung
# 82   Abstimmungs-Arena: Referendum Nachrichtendiens...
# 83              Abstimmungs-Arena: Initiative AHV Plus
# 84        Abstimmungs-Arena: Initiative Grundeinkommen
#
#                                            description  \
# 12   Am sechsten Tag schuf Gott Mensch und Landtier...
# 24   Wie war diese Wahl möglich? Diese Frage stelle...
# 29   Ob der neue Aussenminister nun Ignazio Cassis ...
# 42   Wie weiter mit den Schweizer Medien? Drei Mona...
# 57   Braucht es Radio- und TV-Gebühren? Das ist die...
# 66   Mehr Kühe mit Hörnern – das will die Hornkuh-I...
# 89   Die Burka gibt zu reden. In Österreich ist sie...
# 96   Darf der Bund weiterhin Steuern erheben? Ja, s...
# 95   Die Schweiz hat europaweit eines der strengste...
# 93   Trump gewinnt, Europa rutscht nach rechts. Abe...
# 85   Neue Kampfjets – dafür will der Bundesrat bis ...
# 83   Auch homosexuelle Paare in der Schweiz sollen ...
# 82   Jahr für Jahr werden wir älter – und zwar nich...
# 74   Mehr Geld für die Strasse – das will die sogen...
# 70   Managerlöhne bei Post, SBB und Swisscom sollen...
# 133  In einem sind sich alle einig: Lange Asylverfa...
# 145  Es braucht eine Rentenreform – darin sind sich...
# 142  Beleidigungen, Ehrverletzungen, Morddrohungen ...
# 138  Sollen Sozialversicherungen Detektive einsetze...
# 137  Der Meeresspiegel steigt, extreme Wetterereign...
# 148  Während beim Rahmenabkommen ein Abschluss in w...
# 126  Der Nationalrat debattierte am Mittwoch über d...
# 116  Ob Unternehmenssteuer oder Altersvorsorge: In ...
# 110  Ist die SRG, wie wir sie kennen, bald Geschich...
# 101  Die Grippezeit steht kurz bevor. Sollte man si...
# 123  Neue globale Handelsabkommen wie TTIP sollen d...
# 219  Fast ist Halbzeit in Bern: Was hat die erste L...
# 241  Vor 25 Jahren war der EU-Beitritt für viele ei...
# 240  Rund ums Jahr streiten Politiker in der «Arena...
# 238  Die Schweiz spart – und das erfolgreich: bei d...
# ..                                                 ...
# 55   Langfristig aus der Kernenergie aussteigen und...
# 56   Der Bundesrat will es, fast alle Parteien woll...
# 57   Managerlöhne bei Post, SBB und Swisscom sollen...
# 58   Mehr Geld für die Strasse – das will die sogen...
# 59   Es braucht eine Rentenreform – darin sind sich...
# 60   Wieso ist die nicht bei ihren Kindern? Das hör...
# 61   Die Zukunft unserer Renten – darüber debattier...
# 62   Zwei muslimische Schüler wollen ihrer Lehrerin...
# 63   Den Job zu verlieren – der Albtraum jedes Arbe...
# 64   Die Schraube anziehen bei den Armen – das woll...
# 65   Die Burka gibt zu reden. In Österreich ist sie...
# 66   Bundesrat Johann Schneider-Ammann tritt zurück...
# 67   Einen ökologischen Fussabdruck von einer Erde:...
# 68   Darf der Bund weiterhin Steuern erheben? Ja, s...
# 69   Weihnachtsmärkte in der Schweiz setzen dieses ...
# 70   Ist die SRG, wie wir sie kennen, bald Geschich...
# 71   Die Grippezeit steht kurz bevor. Sollte man si...
# 72   Stau auf den Strassen, verspätete Züge, vollge...
# 73   Donald Trump und das WEF – da treffen Welten a...
# 74   Isst die Schweiz fair genug? Nein, finden die ...
# 75   Das neue Geldspielgesetz schien beschlossene S...
# 76   Der Meeresspiegel steigt, extreme Wetterereign...
# 77   Sämtliche Parlamentarier haben gegen die Servi...
# 78   Nach 45 Jahren Laufzeit müssen Kernkraftwerke ...
# 79   Sara (17), Luis (17) und Andrea (17) moderiere...
# 80   Darf man Embryonen, die im Reagenzglas entsteh...
# 81   Rund ums Jahr streiten Politiker in der «Arena...
# 82   Telefongespräche abhören, Wanzen in Privaträum...
# 83   Zehn Prozent mehr AHV-Rente, das fordert die I...
# 84   Lohn ohne Arbeit, Geld ohne Gegenleistung - ei...
#
#                                                   link
# 12   https://www.srf.ch/sendungen/arena/eine-tieris...
# 24      https://www.srf.ch/sendungen/arena/wieso-trump
# 29   https://www.srf.ch/sendungen/arena/blocher-geg...
# 42   https://www.srf.ch/sendungen/arena/srg-und-pri...
# 57   https://www.srf.ch/sendungen/arena/no-billag-j...
# 66   https://www.srf.ch/sendungen/arena/abstimmungs...
# 89   https://www.srf.ch/sendungen/arena/burka-da-se...
# 96   https://www.srf.ch/sendungen/arena/abstimmungs...
# 95   https://www.srf.ch/sendungen/arena/gut-genug-f...
# 93   https://www.srf.ch/sendungen/arena/kapitalismu...
# 85   https://www.srf.ch/sendungen/arena/kampf-um-di...
# 83   https://www.srf.ch/sendungen/arena/sollen-tamy...
# 82   https://www.srf.ch/sendungen/arena/alle-macht-...
# 74   https://www.srf.ch/sendungen/arena/abstimmungs...
# 70   https://www.srf.ch/sendungen/arena/abstimmungs...
# 133  https://www.srf.ch/sendungen/arena/abstimmungs...
# 145  https://www.srf.ch/sendungen/arena/rentenrefor...
# 142  https://www.srf.ch/sendungen/arena/klick-like-...
# 138  https://www.srf.ch/sendungen/arena/abstimmungs...
# 137  https://www.srf.ch/sendungen/arena/fahren-wir-...
# 148  https://www.srf.ch/sendungen/arena/praesidente...
# 126  https://www.srf.ch/sendungen/arena/inlaendervo...
# 116  https://www.srf.ch/sendungen/arena/am-runden-t...
# 110  https://www.srf.ch/sendungen/arena/no-billag-j...
# 101  https://www.srf.ch/sendungen/arena/impf-oder-s...
# 123  https://www.srf.ch/sendungen/arena/jobs-weg-fr...
# 219  https://www.srf.ch/sendungen/arena/die-parteip...
# 241   https://www.srf.ch/sendungen/arena/auf-in-die-eu
# 240  https://www.srf.ch/sendungen/arena/schoene-bes...
# 238  https://www.srf.ch/sendungen/arena/vergoldete-...
# ..                                                 ...
# 55   https://www.srf.ch/sendungen/arena/abstimmungs...
# 56   https://www.srf.ch/sendungen/arena/eu-debatte-...
# 57   https://www.srf.ch/sendungen/arena/abstimmungs...
# 58   https://www.srf.ch/sendungen/arena/abstimmungs...
# 59   https://www.srf.ch/sendungen/arena/rentenrefor...
# 60   https://www.srf.ch/sendungen/arena/sollte-die-...
# 61   https://www.srf.ch/sendungen/arena/rentenrefor...
# 62   https://www.srf.ch/sendungen/arena/schweiz-ohn...
# 63   https://www.srf.ch/sendungen/arena/ue50-chance...
# 64   https://www.srf.ch/sendungen/arena/sparen-bei-...
# 65   https://www.srf.ch/sendungen/arena/burka-da-se...
# 66   https://www.srf.ch/sendungen/arena/doppelrueck...
# 67   https://www.srf.ch/sendungen/arena/abstimmungs...
# 68   https://www.srf.ch/sendungen/arena/abstimmungs...
# 69   https://www.srf.ch/sendungen/arena/was-stoppt-...
# 70   https://www.srf.ch/sendungen/arena/no-billag-j...
# 71   https://www.srf.ch/sendungen/arena/impf-oder-s...
# 72   https://www.srf.ch/sendungen/arena/ungebremste...
# 73     https://www.srf.ch/sendungen/arena/trump-vs-wef
# 74   https://www.srf.ch/sendungen/arena/abstimmungs...
# 75   https://www.srf.ch/sendungen/arena/abstimmungs...
# 76   https://www.srf.ch/sendungen/arena/fahren-wir-...
# 77   https://www.srf.ch/sendungen/arena/service-pub...
# 78   https://www.srf.ch/sendungen/arena/abstimmungs...
# 79   https://www.srf.ch/sendungen/arena/die-jungen-...
# 80   https://www.srf.ch/sendungen/arena/abstimmungs...
# 81   https://www.srf.ch/sendungen/arena/schoene-bes...
# 82   https://www.srf.ch/sendungen/arena/abstimmungs...
# 83   https://www.srf.ch/sendungen/arena/abstimmungs...
# 84   https://www.srf.ch/sendungen/arena/abstimmungs...
#
# [135 rows x 6 columns]

# %%
### determine number of appearances by guest
guests.name.value_counts()
# Out:
# Petra Gössi                      10
# Albert Rösti                     8
# Regula Rytz                      8
# Ruth Humbel                      7
# Alain Berset                     6
# Christoph Blocher                6
# Rosmarie Quadranti               5
# Christa Tobler                   5
# Tiana Angelina Moser             5
# Elisabeth Schneider-Schneiter    5
# Balthasar Glättli                5
# Gerhard Pfister                  4
# Eric Nussbaumer                  4
# Ruedi Noser                      4
# Tamara Funiciello                4
# Pirmin Bischof                   4
# Cédric Wermuth                   3
# Doris Leuthard                   3
# Martin Landolt                   3
# Paul Rechsteiner                 3
# Markus Ritter                    3
# Christian Levrat                 3
# Claudio Zanetti                  3
# Andreas Glarner                  3
# Valentin Vogt                    3
# Regine Sauter                    3
# Silvan Amberg                    3
# Christine Häsler                 3
# Filippo Lombardi                 3
# Jürg Grossen                     3
# Philipp Müller                   3
# Martin Candinas                  3
# Corrado Pardini                  3
# Irina Studhalter                 2
# Christian Wasserfallen           2
# Katja Gentinetta                 2
# Beat Walti                       2
# Guy Parmelin                     2
# Rudolf Strahm                    2
# Peter Grünenfelder               2
# Jacqueline Badran                2
# Sebastian Frehner                2
# Laura Zimmermann                 2
# Maya Graf                        2
# Ueli Mäder                       2
# Kurt Fluri                       2
# Andreas Kleeb                    2
# Roland Eberle                    2
# Chantal Galladé                  2
# Fabian Molina                    2
# Lukas Reimann                    2
# Otto Hostettler                  2
# Norman Gobbi                     2
# Hans-Ueli Vogt                   2
# Hans-Ulrich Huber                2
# Paul Widmer                      2
# Christa Markwalder               2
# Claude Longchamp                 2
# Monika Rühl                      2
# Silvia Schenker                  2
# Franz Jaeger                     2
# Roland Rino Büchel               2
# Markus Schefer                   2
# Mattea Meyer                     2
# Montassar BenMrad                2
# Barbara Gysi                     2
# Luzian Franzini                  2
# Simonetta Sommaruga              2
# Heinz Brand                      2
# André Moesch                     2
# Martin Bäumle                    2
# Heinz Karrer                     2
# Viola Amherd                     2
# Beat Jans                        2
# Gregor Rutz                      2
# Daniel Jositsch                  2
# Thomas Müller                    2
# Lewin Lempert                    2
# Camille Lothe                    2
# Toni Brunner                     2
# Franz Steinegger                 2
# Yvonne Feri                      2
# Andrea Caroni                    2
# Lukas Bärfuss                    2
# Christian Imark                  2
# Dieter Spiess                    1
# Nicolo Paganini                  1
# Lorenz Hess                      1
# Martina Munz                     1
# Andri Silberschmidt              1
# Andreas Fischlin                 1
# Markus Somm                      1
# Doris Fiala                      1
# Christine Bühler                 1
# Marianne Streiff-Feller          1
# Jean-Paul Rouiller               1
# Nicolas Blancho                  1
# Marco Medici                     1
# Mike Müller                      1
# Martin Friedli                   1
# Luzi Stamm                       1
# Adrian Wüthrich                  1
# Silva Semadeni                   1
# Andreas Missbach                 1
# Doris Bianchi                    1
# Jean-François Steiert            1
# Walter Wobmann                   1
# Barbara Steinemann               1
# Christoph Sigrist                1
# Felix Wolffers                   1
# Silja Häusermann                 1
# Johann Schneider-Ammann          1
# Daniel Straub                    1
# Martin Schlup                    1
# Erich Hess                       1
# Tilman Slembeck                  1
# Alexander Gauland                1
# Ida Glanzmann-Hunkeler           1
# Olivier Kessler                  1
# Valentin Abgottspon              1
# Theo Wehner                      1
# Andreas Burgener                 1
# Evi Allemann                     1
# Marcel Dobler                    1
# Nico Planzer                     1
# Christa Rigozzi                  1
# Urs Vögeli                       1
# Georg Kohler                     1
# Markus Seiler                    1
# Thomas Matter                    1
# Peter Gehler                     1
# Erika Ziltener                   1
# Anita Fetz                       1
# Ruth Dreifuss                    1
# Babette Sigg                     1
# Benjamin Gautschi                1
# Jean-Michel Cina                 1
# Hansjörg Walter                  1
# Hans Grunder                     1
# Eveline Brown                    1
# Andrea Gmür-Schönenberger        1
# Karin Keller-Sutter              1
# Jacqueline Fehr                  1
# Miriam Behrens                   1
# Franz Hohler                     1
# Andreas Frey                     1
# Liliane Maury Pasquier           1
# Niklaus Scherr                   1
# Tiana Moser                      1
# Patrick Dümmler                  1
# Hans Moser                       1
# Lea Stahel                       1
# Monika Bütler                    1
# Sandra Schneider                 1
# Monika Dudle-Ammann              1
# Philipp Gut                      1
# Thomas Weibel                    1
# Adrian Amstutz                   1
# Martina Bircher                  1
# Bastien Girod                    1
# Andreas Züllig                   1
# Magdalena Martullo-Blocher       1
# Sibel Arslan                     1
# Duri Campell                     1
# Alex Baur                        1
# Andrea Huber                     1
# Daniel Lampart                   1
# Raffael Wüthrich                 1
# Thomas Kissling                  1
# Roger Schawinski                 1
# Robin Udry                       1
# Werner Luginbühl                 1
# Gilbert A. Bühler                1
# Damian Müller                    1
# Irène Kälin                      1
# Regula Imperatori                1
# Marianne Binder-Keller           1
# Markus Gygax                     1
# Ursula Haller                    1
# Urs Berner                       1
# Tamara Fretz                     1
# Thierry Burkart                  1
# Kaspar Schuler                   1
# Nadine Masshardt                 1
# Thomas Hurter                    1
# Patrick Walder                   1
# Rudolf Minsch                    1
# Nicole Nickerson                 1
# David Keller                     1
# Michael Hermann                  1
# Dimitri Rougy                    1
# Marcel Dettling                  1
# Jürg Brechbühl                   1
# Manuel Puppis                    1
# Armin Capaul                     1
# Hans Stöckli                     1
# Urs Loher                        1
# Klaus Wellershoff                1
# Ueli Maurer                      1
# Michael Frank                    1
# Thierry Carrel                   1
# Reinhold Harringer               1
# Marco Romano                     1
# Andrea Geissbühler               1
# Josef Dittli                     1
# Werner Salzmann                  1
# Philippe Mastronardi             1
# Samira Marti                     1
# Jean-Philippe Kohl               1
# Barbara Schmid-Federer           1
# Hans-Peter Portmann              1
# Maya Hertig                      1
# Matthias Oesch                   1
# Edith Graf-Litscher              1
# Matthias Müller                  1
# Alfred Heer                      1
# Meret Schneider                  1
# Jean Ziegler                     1
# Thomas Sauter-Servaes            1
# Christian Schönbächler           1
# Christoph Schaltegger            1
# Thomas Minder                    1
# Gabriel Rumo                     1
# Yvette Estermann                 1
# Alessandro Pelizzari             1
# Thomas Heiniger                  1
# Salomé Vogt                      1
# Martin Alder                     1
# Martin Steiger                   1
# Martin Ott                       1
# Silvio Ponti                     1
# Peter Föhn                       1
# Irene Aegerter                   1
# Patrick Benz                     1
# Gerold Bührer                    1
# Anita Weyermann                  1
# Sakib Halilovic                  1
# Natalie Rickli                   1
# Pater Christian Rutishauser      1
# Franziska Barmettler             1
# Regula Stämpfli                  1
# Lukas Wegmüller                  1
# Simon Scherrer                   1
# Urs Iselin                       1
# Julia Onken                      1
# Benedikt Würth                   1
# Pascal Vuichard                  1
# Marco Giglio                     1
# Bernhard Guhl                    1
# Daniel Trappitsch                1
# Rosmarie Zapfl                   1
# Christoph Berger                 1
# Elham Manea                      1
# Jasmin El Sonbati                1
# Name: name, dtype: int64
